# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('/Users/Adit/Desktop/Learnbay/Data-Science/Python/datasets/Students Performance.csv')

# %%
data.head()
# Out:
#    gender  section   house parental level of education          fees  \
# 0  female  group B     Red           bachelor's degree      standard
# 1  female  group C  Yellow                some college      standard
# 2  female  group B  Yellow             master's degree      standard
# 3    male  group A  Yellow          associate's degree  free/reduced
# 4    male  group C  Yellow                some college      standard
#
#      tutions  math score  english score  science score  social studies score  \
# 0       none          72             72             74                    56
# 1  completed          69             90             88                    74
# 2       none          90             95             93                    91
# 3       none          47             57             44                    46
# 4       none          76             78             75                    74
#
#    computer application score  age  weight (in kgs)  height (in cms)
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   section                      1000 non-null   object
#  2   house                        1000 non-null   object
#  3   parental level of education  1000 non-null   object
#  4   fees                         1000 non-null   object
#  5   tutions                      1000 non-null   object
#  6   math score                   1000 non-null   int64
#  7   english score                1000 non-null   int64
#  8   science score                1000 non-null   int64
#  9   social studies score         1000 non-null   int64
#  10  computer application score   1000 non-null   int64
#  11  age                          1000 non-null   int64
#  12  weight (in kgs)              1000 non-null   int64
# ...

# %%
data.describe()
# Out:
#        math score  english score  science score  social studies score  \
# count  1000.00000    1000.000000    1000.000000           1000.000000
# mean     66.08900      69.169000      68.054000             69.152000
# std      15.16308      14.600192      15.195657             14.689134
# min       0.00000      17.000000      10.000000             45.000000
# 25%      57.00000      59.000000      57.750000             56.000000
# 50%      66.00000      70.000000      69.000000             69.000000
# 75%      77.00000      79.000000      79.000000             82.000000
# max     100.00000     100.000000     100.000000             95.000000
#
#        computer application score          age  weight (in kgs)  \
# count                 1000.000000  1000.000000      1000.000000
# mean                    60.581000    16.004000        62.519000
# std                     21.085019     1.400695        10.496371
# min                     25.000000    14.000000        45.000000
# ...

# %%
data.isnull().sum()
# Out:
# gender                         0
# section                        0
# house                          0
# parental level of education    0
# fees                           0
# tutions                        0
# math score                     0
# english score                  0
# science score                  0
# social studies score           0
# computer application score     0
# age                            0
# weight (in kgs)                0
# height (in cms)                0
# dtype: int64

# %%
data['tutions'] = data['tutions'].replace('none','No tution')

# %%
data.head()
# Out:
#    gender  section   house parental level of education          fees  \
# 0  female  group B     Red           bachelor's degree      standard
# 1  female  group C  Yellow                some college      standard
# 2  female  group B  Yellow             master's degree      standard
# 3    male  group A  Yellow          associate's degree  free/reduced
# 4    male  group C  Yellow                some college      standard
#
#      tutions  math score  english score  science score  social studies score  \
# 0  No tution          72             72             74                    56
# 1  completed          69             90             88                    74
# 2  No tution          90             95             93                    91
# 3  No tution          47             57             44                    46
# 4  No tution          76             78             75                    74
#
#    computer application score  age  weight (in kgs)  height (in cms)
# ...

# %%
data['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
labels = 'Female' , 'Male'
size = list(data['gender'].value_counts())
fig1 = plt.figure(figsize=(20,20))
explode = (0.0,0.0)
fig1,ax1 = plt.subplots()
ax1.pie(size,explode=explode,labels=labels,autopct ='%1.1f%%',shadow=True ,startangle = 90)

# explode differentiates both categories in pie chart
# in autopct 1.1 means 1 decimal, if we give 1.12 then 12 decimal points will be there
# Out:
# ([<matplotlib.patches.Wedge at 0x7f80fd36c3d0>,
# ...
#  [Text(-1.0982417038160106, -0.062170410962984174, 'Female'),
#   Text(1.0982417038160106, 0.06217041096298404, 'Male')],
#  [Text(-0.5990409293541875, -0.03391113325253682, '51.8%'),
#   Text(0.5990409293541875, 0.033911133252536745, '48.2%')])

# %%
data['section'].value_counts()
# Out:
# group C    319
# group D    262
# group B    190
# group E    140
# group A     89
# Name: section, dtype: int64

# %%
list(data['section'].value_counts())
# Out:
# [319, 262, 190, 140, 89]

# %%
list(data.section.unique())
# Out:
# ['group B', 'group C', 'group A', 'group D', 'group E']

# %%
#x = list(data.section.unique())
x = ['Group C','Group D','Group B','Group E','Group A']
y = list(data['section'].value_counts())

x_pos = [i for i , _ in enumerate(x)]

plt.xlabel('Groups')
plt.ylabel('No. of Students')
plt.bar(x_pos,size,color = 'red')
plt.xticks(x_pos,x)
plt.show()

# %%
data['parental level of education'].value_counts(normalize=True)
# Out:
# some college          0.226
# associate's degree    0.222
# high school           0.196
# some high school      0.179
# bachelor's degree     0.118
# master's degree       0.059
# Name: parental level of education, dtype: float64

# %%
data['weight (in kgs)'].value_counts(bins=5)
# Out:
# (53.0, 61.0]      302
# (61.0, 69.0]      226
# (44.959, 53.0]    207
# (69.0, 77.0]      152
# (77.0, 85.0]      113
# Name: weight (in kgs), dtype: int64

# %%
ax = sns.violinplot(x = 'gender',y = 'weight (in kgs)',data=data)

# %%
ax = data.boxplot(column=['math score','english score','science score'])

# %%
sns.catplot(x='gender',y='english score',data=data)

# %%
sns.catplot(x='section',y='english score',hue='gender',dodge=True,data=data)

# %%
data['math score'].hist(bins=10,histtype='bar',align = 'mid',stacked=True)
# Out:
# <AxesSubplot:>

# %%
ax = sns.swarmplot(x='section',y='science score', hue='gender',data=data,dodge=True)
# Out:
# /Users/Adit/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 20.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/Adit/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 14.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/Adit/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 41.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Users/Adit/opt/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 30.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
data.groupby(['gender','section']).size().unstack()
# Out:
# section  group A  group B  group C  group D  group E
# gender
# female        36      104      180      129       69
# male          53       86      139      133       71

# %%
data.plot(kind='scatter',x='age',y='height (in cms)',marker='o')
plt.show()

# %%
ax = sns.pointplot(x='section',y='math score',hue = 'gender', data=data)

# %%
sns.heatmap(data.corr(),fmt='.2g',annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.regplot(x='math score',y='english score',data=data)
# Out:
# <AxesSubplot:xlabel='math score', ylabel='english score'>
