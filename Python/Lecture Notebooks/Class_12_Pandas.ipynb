# %% [markdown]
# # Indexing and SLicing on Dataframe

# %%
import pandas as pd

# %%
citi_ride = pd.read_csv('datasets/citibike_tripdata.csv')
citi_ride.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22              3194
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
citi_ride.tail(3)
# Out:
#        tripduration            starttime             stoptime  \
# 32425           316  2018-05-30 13:49:51  2018-05-30 13:55:08
# 32426          1130  2018-05-30 13:50:52  2018-05-30 14:09:42
# 32427           369  2018-05-30 13:50:58  2018-05-30 13:57:08
#
#        start station id   start station name  end station id end station name  \
# 32425              3220    5 Corners Library            3195          Sip Ave
# 32426              3281  Leonard Gordon Park            3213   Van Vorst Park
# 32427              3220    5 Corners Library            3207      Oakland Ave
#
#        bikeid name_localizedValue    usertype
# 32425   29260   Annual Membership  Subscriber
# 32426   26239   Annual Membership  Subscriber
# 32427   33660   Annual Membership  Subscriber

# %%
# arr[row, col]
# df[col, row]

# To access one column
citi_ride['start station name'].head()
# Out:
# 0         Harborside
# 1           Grand St
# 2    McGinley Square
# 3          City Hall
# 4        Oakland Ave
# Name: start station name, dtype: object

# %%
# To Access multiple column
citi_ride[['start station name','end station name']]
# Out:
#         start station name end station name
# 0               Harborside     Newport Pkwy
# 1                 Grand St        City Hall
# 2          McGinley Square     Lincoln Park
# 3                City Hall    Grove St PATH
# 4              Oakland Ave          Sip Ave
# ...                    ...              ...
# 32423          Paulus Hook      Dixon Mills
# 32424         Newport PATH       Harborside
# 32425    5 Corners Library          Sip Ave
# 32426  Leonard Gordon Park   Van Vorst Park
# 32427    5 Corners Library      Oakland Ave
#
# [32428 rows x 2 columns]

# %%
# Cell value
# citi_ride['start station id'][2]
# citi_ride.at[2, 'start station id']
# citi_ride.at[2, 'start station id'] = 31940
# citi_ride.head()
# Out:
#    tripduration            starttime             stoptime  start station id  \
# 0           338  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# 1          1482  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# 2           232  2018-05-01 01:31:29  2018-05-01 01:35:22             31940
# 3           190  2018-05-01 02:03:29  2018-05-01 02:06:40              3185
# 4           303  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
#
#   start station name  end station id end station name  bikeid  \
# 0         Harborside            3199     Newport Pkwy   33558
# 1           Grand St            3185        City Hall   33593
# 2    McGinley Square            3193     Lincoln Park   29217
# 3          City Hall            3186    Grove St PATH   29662
# 4        Oakland Ave            3195          Sip Ave   15271
#
#                        name_localizedValue    usertype
# 0                        Annual Membership  Subscriber
# ...

# %%
# Accessing a row - .loc(Explicit index), .iloc(implict index)
citi_ride.loc[2]
# Out:
# tripduration                                               232
# starttime                                  2018-05-01 01:31:29
# stoptime                                   2018-05-01 01:35:22
# start station id                                         31940
# start station name                             McGinley Square
# end station id                                            3193
# end station name                                  Lincoln Park
# bikeid                                                   29217
# name_localizedValue    FREE Bonus Month with Annual Membership
# usertype                                            Subscriber
# Name: 2, dtype: object

# %%
citi_ride.iloc[2]
# Out:
# tripduration                                               232
# starttime                                  2018-05-01 01:31:29
# stoptime                                   2018-05-01 01:35:22
# start station id                                         31940
# start station name                             McGinley Square
# end station id                                            3193
# end station name                                  Lincoln Park
# bikeid                                                   29217
# name_localizedValue    FREE Bonus Month with Annual Membership
# usertype                                            Subscriber
# Name: 2, dtype: object

# %%
citi_ride.index = ['ride_'+str(i) for i in range(1, len(citi_ride.tripduration)+1)]

# %%
citi_ride.head()
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
#
#         start station id start station name  end station id end station name  \
# ride_1              3639         Harborside            3199     Newport Pkwy
# ride_2              3681           Grand St            3185        City Hall
# ride_3             31940    McGinley Square            3193     Lincoln Park
# ride_4              3185          City Hall            3186    Grove St PATH
# ride_5              3207        Oakland Ave            3195          Sip Ave
#
#         bikeid                      name_localizedValue    usertype
# ...

# %%
citi_ride.loc['ride_3']
# Out:
# tripduration                                               232
# starttime                                  2018-05-01 01:31:29
# stoptime                                   2018-05-01 01:35:22
# start station id                                         31940
# start station name                             McGinley Square
# end station id                                            3193
# end station name                                  Lincoln Park
# bikeid                                                   29217
# name_localizedValue    FREE Bonus Month with Annual Membership
# usertype                                            Subscriber
# Name: ride_3, dtype: object

# %%
citi_ride.iloc[2]
# Out:
# tripduration                                               232
# starttime                                  2018-05-01 01:31:29
# stoptime                                   2018-05-01 01:35:22
# start station id                                         31940
# start station name                             McGinley Square
# end station id                                            3193
# end station name                                  Lincoln Park
# bikeid                                                   29217
# name_localizedValue    FREE Bonus Month with Annual Membership
# usertype                                            Subscriber
# Name: ride_3, dtype: object

# %%
# Slicing on Dataframe
new_ride_data = citi_ride[:10]
new_ride_data
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id     start station name  end station id  \
# ride_1               3639             Harborside            3199
# ride_2               3681               Grand St            3185
# ...

# %%
new_ride_data['ride_4':'ride_7']
# Out:
#         tripduration            starttime             stoptime  \
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#         start station id     start station name  end station id  \
# ride_4              3185              City Hall            3186
# ride_5              3207            Oakland Ave            3195
# ride_6              3194        McGinley Square            3195
# ride_7              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid                   name_localizedValue  \
# ride_4    Grove St PATH   29662                               24 Hour
# ride_5          Sip Ave   15271                     Annual Membership
# ride_6          Sip Ave   29298                     Annual Membership
# ...

# %%
new_ride_data.loc['ride_4':'ride_7']
# Out:
#         tripduration            starttime             stoptime  \
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#         start station id     start station name  end station id  \
# ride_4              3185              City Hall            3186
# ride_5              3207            Oakland Ave            3195
# ride_6              3194        McGinley Square            3195
# ride_7              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid                   name_localizedValue  \
# ride_4    Grove St PATH   29662                               24 Hour
# ride_5          Sip Ave   15271                     Annual Membership
# ride_6          Sip Ave   29298                     Annual Membership
# ...

# %%
new_ride_data.iloc[3:7]
# Out:
#         tripduration            starttime             stoptime  \
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#         start station id     start station name  end station id  \
# ride_4              3185              City Hall            3186
# ride_5              3207            Oakland Ave            3195
# ride_6              3194        McGinley Square            3195
# ride_7              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid                   name_localizedValue  \
# ride_4    Grove St PATH   29662                               24 Hour
# ride_5          Sip Ave   15271                     Annual Membership
# ride_6          Sip Ave   29298                     Annual Membership
# ...

# %%
# new_ride_data['ride_4':'ride_7']['tripduration':'bikeid']
# Out:
# Empty DataFrame
# Columns: [tripduration, starttime, stoptime, start station id, start station name, end station id, end station name, bikeid, name_localizedValue, usertype]
# Index: []

# %%
new_ride_data.loc['ride_4':'ride_7','tripduration':'bikeid']
# Out:
#         tripduration            starttime             stoptime  \
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6           176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
#
#         start station id     start station name  end station id  \
# ride_4              3185              City Hall            3186
# ride_5              3207            Oakland Ave            3195
# ride_6              3194        McGinley Square            3195
# ride_7              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid
# ride_4    Grove St PATH   29662
# ride_5          Sip Ave   15271
# ride_6          Sip Ave   29298
# ride_7    Grove St PATH   33619

# %%
new_ride_data.loc[new_ride_data['tripduration']>200]
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3           232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_7           577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_2              3681               Grand St            3185
# ride_3             31940        McGinley Square            3193
# ride_5              3207            Oakland Ave            3195
# ride_7              3225  Baldwin at Montgomery            3186
# ride_8              3207            Oakland Ave            3185
# ...

# %%
new_ride_data.loc[new_ride_data['tripduration']>200, 'starttime':'end station name']
# Out:
#                   starttime             stoptime  start station id  \
# ride_1  2018-05-01 00:04:47  2018-05-01 00:10:25              3639
# ride_2  2018-05-01 01:31:10  2018-05-01 01:55:53              3681
# ride_3  2018-05-01 01:31:29  2018-05-01 01:35:22             31940
# ride_5  2018-05-01 04:27:12  2018-05-01 04:32:16              3207
# ride_7  2018-05-01 05:05:46  2018-05-01 05:15:23              3225
# ride_8  2018-05-01 05:11:50  2018-05-01 05:25:41              3207
# ride_9  2018-05-01 05:12:07  2018-05-01 05:18:42              3225
#
#            start station name  end station id end station name
# ride_1             Harborside            3199     Newport Pkwy
# ride_2               Grand St            3185        City Hall
# ride_3        McGinley Square            3193     Lincoln Park
# ride_5            Oakland Ave            3195          Sip Ave
# ride_7  Baldwin at Montgomery            3186    Grove St PATH
# ...

# %%
filtered_data = new_ride_data.loc[new_ride_data['tripduration']>200].loc[new_ride_data['usertype'] == 'Subscriber'].loc[new_ride_data['name_localizedValue']=='Annual Membership']
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_5              3207            Oakland Ave            3195
# ride_8              3207            Oakland Ave            3185
# ride_9              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid name_localizedValue    usertype
# ride_1     Newport Pkwy   33558   Annual Membership  Subscriber
# ride_5          Sip Ave   15271   Annual Membership  Subscriber
# ride_8        City Hall   33624   Annual Membership  Subscriber
# ride_9    Grove St PATH   26300   Annual Membership  Subscriber

# %%
filtered_data = new_ride_data.loc[((new_ride_data['tripduration'] > 200) & (new_ride_data['usertype'] == 'Subscriber')) & (new_ride_data['name_localizedValue']=='Annual Membership')]
filtered_data
# Out:
#         tripduration            starttime             stoptime  \
# ride_1           338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_5           303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_8           830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9           395  2018-05-01 05:12:07  2018-05-01 05:18:42
#
#         start station id     start station name  end station id  \
# ride_1              3639             Harborside            3199
# ride_5              3207            Oakland Ave            3195
# ride_8              3207            Oakland Ave            3185
# ride_9              3225  Baldwin at Montgomery            3186
#
#        end station name  bikeid name_localizedValue    usertype
# ride_1     Newport Pkwy   33558   Annual Membership  Subscriber
# ride_5          Sip Ave   15271   Annual Membership  Subscriber
# ride_8        City Hall   33624   Annual Membership  Subscriber
# ride_9    Grove St PATH   26300   Annual Membership  Subscriber

# %%
new_ride_data['New_field'] = new_ride_data['start station id'] + new_ride_data['end station id']
# Out:
# <ipython-input-64-bc2369876f5b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ride_data['New_field'] = new_ride_data['start station id'] + new_ride_data['end station id']

# %%
new_ride_data.loc[:, 'New_field'] = new_ride_data['start station id'] + new_ride_data['end station id']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/pandas/core/indexing.py:1676: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(ilocs[0], value, pi)

# %%
new_ride_data.insert(4, 'New_field1', new_ride_data['New_field']*2)

# %%
new_ride_data
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id  New_field1     start station name  end station id  \
# ride_1               3639       13676             Harborside            3199
# ride_2               3681       13732               Grand St            3185
# ...

# %%
new_ride_data.insert(4, 'New_field2', np.NaN)

# %%
new_ride_data['New_field2'] = new_ride_data['New_field2'].replace(np.NaN, 100)
# Out:
# <ipython-input-82-0335bb633c0b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_ride_data['New_field2'] = new_ride_data['New_field2'].replace(np.NaN, 100)

# %%
new_ride_data
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id  New_field2  New_field1     start station name  \
# ride_1               3639       100.0       13676             Harborside
# ride_2               3681       100.0       13732               Grand St
# ...

# %% [markdown]
# # Iterating over dataframe

# %%
for row in new_ride_data.itertuples():
#     print(row, type(row))
    print(row[0])
    print(row[1])
    print()
# Out:
# ride_1
# 338
#
# ride_2
# 1482
#
# ride_3
# 232
#
# ride_4
# 190
#
# ride_5
# 303
#
# ride_6
# 176
#
# ride_7
# 577
#
# ride_8
# 830
#
# ride_9
# 395
#
# ride_10
# 170

# %%
list(enumerate('Python'))
# Out:
# [(0, 'P'), (1, 'y'), (2, 't'), (3, 'h'), (4, 'o'), (5, 'n')]

# %%
for row in new_ride_data.iterrows():
    print('row_index = ', row[0])
    print('value = ', row[1])
    print()
# Out:
# row_index =  ride_1
# value =  tripduration                           338
# starttime              2018-05-01 00:04:47
# stoptime               2018-05-01 00:10:25
# start station id                      3639
# New_field2                           100.0
# New_field1                           13676
# start station name              Harborside
# end station id                        3199
# end station name              Newport Pkwy
# bikeid                               33558
# name_localizedValue      Annual Membership
# usertype                        Subscriber
# New_field                             6838
# Name: ride_1, dtype: object
#
# row_index =  ride_2
# value =  tripduration                          1482
# starttime              2018-05-01 01:31:10
# stoptime               2018-05-01 01:55:53
# start station id                      3681
# New_field2                           100.0
# New_field1                           13732
# start station name                Grand St
# ...

# %%
for col_name, values in new_ride_data.iteritems():
    print('Col_name = ',col_name)
    print(values)
    print()
# Out:
# Col_name =  tripduration
# ride_1      338
# ride_2     1482
# ride_3      232
# ride_4      190
# ride_5      303
# ride_6      176
# ride_7      577
# ride_8      830
# ride_9      395
# ride_10     170
# Name: tripduration, dtype: int64
#
# Col_name =  starttime
# ride_1     2018-05-01 00:04:47
# ride_2     2018-05-01 01:31:10
# ride_3     2018-05-01 01:31:29
# ride_4     2018-05-01 02:03:29
# ride_5     2018-05-01 04:27:12
# ride_6     2018-05-01 04:37:05
# ride_7     2018-05-01 05:05:46
# ride_8     2018-05-01 05:11:50
# ride_9     2018-05-01 05:12:07
# ride_10    2018-05-01 05:13:52
# Name: starttime, dtype: object
#
# Col_name =  stoptime
# ride_1     2018-05-01 00:10:25
# ride_2     2018-05-01 01:55:53
# ride_3     2018-05-01 01:35:22
# ride_4     2018-05-01 02:06:40
# ride_5     2018-05-01 04:32:16
# ride_6     2018-05-01 04:40:01
# ride_7     2018-05-01 05:15:23
# ride_8     2018-05-01 05:25:41
# ride_9     2018-05-01 05:18:42
# ride_10    2018-05-01 05:16:43
# ...

# %% [markdown]
# # Reshaping a dataframe

# %%
avocado_multi_index = pd.read_csv('datasets/avocado.csv', index_col = ['Region', 'Type'])
avocado_multi_index.loc['Atlanta'].loc['organic']
# Out:
# Small Bags        89424.11
# Large Bags          207.08
# Total Bags        89631.19
# Total Volume     190257.38
# AveragePrice           1.7
# Date            2018-03-25
# Name: organic, dtype: object

# %%
avocado_multi_index
# Out:
#                            Small Bags  Large Bags  Total Bags  Total Volume  \
# Region       Type
# Atlanta      organic         89424.11      207.08    89631.19     190257.38
#              conventional   102717.50      153.00   102870.50     202790.74
# Boston       organic        120465.39       18.83   120484.22     236822.98
#              conventional   136877.43       60.60   136938.03     239135.67
# California   organic         66273.89       46.58    66320.47     179041.72
#              conventional   103033.73      186.20   106984.89    1203274.11
# NewYork      organic        119694.95       92.29   124214.59     777300.99
#              conventional   193813.92      196.57   197281.89     904333.98
# SanFrancisco organic        231913.11     1286.43   236417.93    1051308.50
#              conventional   162913.33      609.20   166836.16     984000.13
#
#                            AveragePrice        Date
# Region       Type
# ...

# %%
avocado_multi_index = pd.read_csv('datasets/avocado.csv')
avocado_multi_index.pivot(index = 'Region', columns = 'Type').AveragePrice.organic.sum()
# Out:
# 7.640000000000001

# %%
# Melting a dataframe
us_temp = pd.read_csv('datasets/us_temp.csv')
us_temp
# Out:
#    months_name  Atlanta  Buffalo  New York City  San Francisco  Washington
# 0      January       52       31             38             57          43
# 1     February       57       33             42             60          47
# 2        March       65       42             50             62          56
# 3        April       73       55             61             63          67
# 4          May       80       67             71             64          75
# 5         June       86       75             79             66          84
# 6         July       89       80             84             67          88
# 7       August       88       78             83             68          87
# 8    September       82       71             75             70          80
# 9      October       73       59             64             69          68
# 10    November       64       48             54             63          58
# ...

# %%
us_melt_temp = pd.melt(us_temp, id_vars = ['months_name'], var_name = 'City_name', value_name = 'Temperature')
us_melt_temp[us_melt_temp['City_name']== 'Atlanta']
# Out:
#    months_name City_name  Temperature
# 0      January   Atlanta           52
# 1     February   Atlanta           57
# 2        March   Atlanta           65
# 3        April   Atlanta           73
# 4          May   Atlanta           80
# 5         June   Atlanta           86
# 6         July   Atlanta           89
# 7       August   Atlanta           88
# 8    September   Atlanta           82
# 9      October   Atlanta           73
# 10    November   Atlanta           64
# 11    December   Atlanta           54

# %% [markdown]
# # Grouping the data

# %%
new_ride_data
# Out:
#          tripduration            starttime             stoptime  \
# ride_1            338  2018-05-01 00:04:47  2018-05-01 00:10:25
# ride_2           1482  2018-05-01 01:31:10  2018-05-01 01:55:53
# ride_3            232  2018-05-01 01:31:29  2018-05-01 01:35:22
# ride_4            190  2018-05-01 02:03:29  2018-05-01 02:06:40
# ride_5            303  2018-05-01 04:27:12  2018-05-01 04:32:16
# ride_6            176  2018-05-01 04:37:05  2018-05-01 04:40:01
# ride_7            577  2018-05-01 05:05:46  2018-05-01 05:15:23
# ride_8            830  2018-05-01 05:11:50  2018-05-01 05:25:41
# ride_9            395  2018-05-01 05:12:07  2018-05-01 05:18:42
# ride_10           170  2018-05-01 05:13:52  2018-05-01 05:16:43
#
#          start station id  New_field2  New_field1     start station name  \
# ride_1               3639       100.0       13676             Harborside
# ride_2               3681       100.0       13732               Grand St
# ...

# %%
grouped_data = new_ride_data.groupby('start station name')
grouped_data

# %%
list(grouped_data)[2][1]
# Out:
#         tripduration            starttime             stoptime  \
# ride_2          1482  2018-05-01 01:31:10  2018-05-01 01:55:53
#
#         start station id  New_field2  New_field1 start station name  \
# ride_2              3681       100.0       13732           Grand St
#
#         end station id end station name  bikeid name_localizedValue  usertype  \
# ride_2            3185        City Hall   33593             24 Hour  Customer
#
#         New_field
# ride_2       6866

# %%
grouped_data.get_group('City Hall')
# Out:
#         tripduration            starttime             stoptime  \
# ride_4           190  2018-05-01 02:03:29  2018-05-01 02:06:40
#
#         start station id  New_field2  New_field1 start station name  \
# ride_4              3185       100.0       12742          City Hall
#
#         end station id end station name  bikeid name_localizedValue  usertype  \
# ride_4            3186    Grove St PATH   29662             24 Hour  Customer
#
#         New_field
# ride_4       6371

# %% [markdown]
# # Sorting the dataframe

# %%
unsorted_imdb_rating = pd.read_csv(r'./datasets/unsorted_imdb_rating.csv')

# %%
import random
lst = list(range(10))
random.shuffle(lst)
unsorted_imdb_rating.index = lst

# %%
unsorted_imdb_rating
# Out:
#    star_rating                                          title      genre  \
# 6          9.3                       The Shawshank Redemption      Crime
# 2          9.1                                  The Godfather      Crime
# 3          9.2                         The Godfather: Part II      Crime
# 8          9.0                                The Dark Knight     Action
# 0          8.9                                   Pulp Fiction      Crime
# 4          8.8                                   12 Angry Men      Drama
# 7          8.7                 The Good, the Bad and the Ugly    Western
# 1          8.9  The Lord of the Rings: The Return of the King  Adventure
# 5          8.3                               Schindler's List  Biography
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 6       142
# 2       175
# 3       200
# 8       152
# 0       154
# 4        96
# 7       161
# 1       201
# 5       195
# 9       139

# %%
unsorted_imdb_rating.sort_index(axis = 0)
# Out:
#    star_rating                                          title      genre  \
# 0          8.9                                   Pulp Fiction      Crime
# 1          8.9  The Lord of the Rings: The Return of the King  Adventure
# 2          9.1                                  The Godfather      Crime
# 3          9.2                         The Godfather: Part II      Crime
# 4          8.8                                   12 Angry Men      Drama
# 5          8.3                               Schindler's List  Biography
# 6          9.3                       The Shawshank Redemption      Crime
# 7          8.7                 The Good, the Bad and the Ugly    Western
# 8          9.0                                The Dark Knight     Action
# 9          8.1                                     Fight Club      Drama
#
#    duration
# 0       154
# 1       201
# 2       175
# 3       200
# 4        96
# 5       195
# 6       142
# 7       161
# 8       152
# 9       139

# %%
unsorted_imdb_rating.sort_index(ascending = False)
# Out:
#    star_rating                                          title      genre  \
# 9          8.1                                     Fight Club      Drama
# 8          9.0                                The Dark Knight     Action
# 7          8.7                 The Good, the Bad and the Ugly    Western
# 6          9.3                       The Shawshank Redemption      Crime
# 5          8.3                               Schindler's List  Biography
# 4          8.8                                   12 Angry Men      Drama
# 3          9.2                         The Godfather: Part II      Crime
# 2          9.1                                  The Godfather      Crime
# 1          8.9  The Lord of the Rings: The Return of the King  Adventure
# 0          8.9                                   Pulp Fiction      Crime
#
#    duration
# 9       139
# 8       152
# 7       161
# 6       142
# 5       195
# 4        96
# 3       200
# 2       175
# 1       201
# 0       154

# %%
unsorted_imdb_rating.sort_index(ascending = True, axis = 1)
# Out:
#    duration      genre  star_rating  \
# 6       142      Crime          9.3
# 2       175      Crime          9.1
# 3       200      Crime          9.2
# 8       152     Action          9.0
# 0       154      Crime          8.9
# 4        96      Drama          8.8
# 7       161    Western          8.7
# 1       201  Adventure          8.9
# 5       195  Biography          8.3
# 9       139      Drama          8.1
#
#                                            title
# 6                       The Shawshank Redemption
# 2                                  The Godfather
# 3                         The Godfather: Part II
# 8                                The Dark Knight
# 0                                   Pulp Fiction
# 4                                   12 Angry Men
# 7                 The Good, the Bad and the Ugly
# 1  The Lord of the Rings: The Return of the King
# 5                               Schindler's List
# 9                                     Fight Club

# %%
# Sorting based on values
unsorted_imdb_rating.sort_values(by = 'duration').index
# Out:
#    star_rating                                          title      genre  \
# 4          8.8                                   12 Angry Men      Drama
# 9          8.1                                     Fight Club      Drama
# 6          9.3                       The Shawshank Redemption      Crime
# 8          9.0                                The Dark Knight     Action
# 0          8.9                                   Pulp Fiction      Crime
# 7          8.7                 The Good, the Bad and the Ugly    Western
# 2          9.1                                  The Godfather      Crime
# 5          8.3                               Schindler's List  Biography
# 3          9.2                         The Godfather: Part II      Crime
# 1          8.9  The Lord of the Rings: The Return of the King  Adventure
#
#    duration
# 4        96
# 9       139
# 6       142
# 8       152
# 0       154
# 7       161
# 2       175
# 5       195
# 3       200
# 1       201

# %%
unsorted_imdb_rating.sort_values(by = ['genre', 'duration', ])
# Out:
#    star_rating                                          title      genre  \
# 8          9.0                                The Dark Knight     Action
# 1          8.9  The Lord of the Rings: The Return of the King  Adventure
# 5          8.3                               Schindler's List  Biography
# 6          9.3                       The Shawshank Redemption      Crime
# 0          8.9                                   Pulp Fiction      Crime
# 2          9.1                                  The Godfather      Crime
# 3          9.2                         The Godfather: Part II      Crime
# 4          8.8                                   12 Angry Men      Drama
# 9          8.1                                     Fight Club      Drama
# 7          8.7                 The Good, the Bad and the Ugly    Western
#
#    duration
# 8       152
# 1       201
# 5       195
# 6       142
# 0       154
# 2       175
# 3       200
# 4        96
# 9       139
# 7       161

# %% [markdown]
# # Handling Missing data

# %%
weather_dataset = pd.read_csv('datasets/ny_weather.csv')
weather_dataset
# Out:
#          Date  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0    1/1/2016         38.0      23.0      52.0                 30.03
# 1    1/2/2016         36.0      18.0      46.0                 30.02
# 2    1/3/2016          NaN       NaN      47.0                 29.86
# 3    1/6/2016         33.0       NaN      35.0                   NaN
# 4    1/7/2016         39.0      11.0      33.0                 30.28
# 5    1/8/2016         39.0      29.0       NaN                 30.20
# 6    1/9/2016         44.0      38.0      77.0                 30.16
# 7   1/10/2016          NaN      46.0       NaN                   NaN
# 8   1/11/2016         33.0       8.0      37.0                 29.92
# 9   1/12/2016         35.0       NaN      53.0                 29.85
# 10  1/13/2016         26.0       4.0       NaN                 29.94
# 11  1/14/2016          NaN      12.0      47.0                   NaN
# 12  1/17/2016         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.Temperature.isna()
# Out:
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10    False
# 11     True
# 12    False
# 13    False
# Name: Temperature, dtype: bool

# %%
weather_dataset[weather_dataset.Temperature.notna()]['Temperature']
# Out:
# 0     38.0
# 1     36.0
# 3     33.0
# 4     39.0
# 5     39.0
# 6     44.0
# 8     33.0
# 9     35.0
# 10    26.0
# 12    36.0
# 13    25.0
# Name: Temperature, dtype: float64

# %%
weather_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  14 non-null     object
#  1   Temperature           11 non-null     float64
#  2   DewPoint              11 non-null     float64
#  3   Humidity              11 non-null     float64
#  4   Sea Level PressureIn  11 non-null     float64
#  5   VisibilityMiles       12 non-null     float64
#  6   WindSpeedMPH          10 non-null     float64
#  7   Event                 11 non-null     object
# dtypes: float64(6), object(2)
# memory usage: 1.0+ KB

# %%
weather_dataset.Temperature.isnull().sum()
# Out:
# 3

# %%
weather_dataset.Temperature.isna().sum()
# Out:
# 3

# %%
weather_dataset.Temperature.notna().sum()
# Out:
# 11

# %%
weather_dataset.Temperature.notnull().sum()
# Out:
# 11

# %%
# Parsing the date time column while reading csv file
weather_dataset = pd.read_csv('datasets/ny_weather.csv', parse_dates = ['Date'])
weather_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Date                  14 non-null     datetime64[ns]
#  1   Temperature           11 non-null     float64
#  2   DewPoint              11 non-null     float64
#  3   Humidity              11 non-null     float64
#  4   Sea Level PressureIn  11 non-null     float64
#  5   VisibilityMiles       12 non-null     float64
#  6   WindSpeedMPH          10 non-null     float64
#  7   Event                 11 non-null     object
# dtypes: datetime64[ns](1), float64(6), object(1)
# memory usage: 1.0+ KB

# %%
# Changing the type of a column to a particule data type
weather_dataset.Temperature.replace(np.NaN, 0).astype('int')
# Out:
# 0     38
# 1     36
# 2      0
# 3     33
# 4     39
# 5     39
# 6     44
# 7      0
# 8     33
# 9     35
# 10    26
# 11     0
# 12    36
# 13    25
# Name: Temperature, dtype: int64

# %%
weather_dataset.set_index('Date', inplace = True)

# %%
weather_dataset
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-03          NaN       NaN      47.0                 29.86
# 2016-01-06         33.0       NaN      35.0                   NaN
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-08         39.0      29.0       NaN                 30.20
# 2016-01-09         44.0      38.0      77.0                 30.16
# 2016-01-10          NaN      46.0       NaN                   NaN
# 2016-01-11         33.0       8.0      37.0                 29.92
# 2016-01-12         35.0       NaN      53.0                 29.85
# 2016-01-13         26.0       4.0       NaN                 29.94
# 2016-01-14          NaN      12.0      47.0                   NaN
# 2016-01-17         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.fillna(0)
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-03          0.0       0.0      47.0                 29.86
# 2016-01-06         33.0       0.0      35.0                  0.00
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-08         39.0      29.0       0.0                 30.20
# 2016-01-09         44.0      38.0      77.0                 30.16
# 2016-01-10          0.0      46.0       0.0                  0.00
# 2016-01-11         33.0       8.0      37.0                 29.92
# 2016-01-12         35.0       0.0      53.0                 29.85
# 2016-01-13         26.0       4.0       0.0                 29.94
# 2016-01-14          0.0      12.0      47.0                  0.00
# 2016-01-17         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.fillna({'Temperature' : 0,
                         'DewPoint' : 0,
                         'Humidity' : 0,
             'Sea Level PressureIn' : 0,
                  'VisibilityMiles' : 0,
                     'WindSpeedMPH' : 0,
                            'Event' : "No Event"
                     })
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-03          0.0       0.0      47.0                 29.86
# 2016-01-06         33.0       0.0      35.0                  0.00
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-08         39.0      29.0       0.0                 30.20
# 2016-01-09         44.0      38.0      77.0                 30.16
# 2016-01-10          0.0      46.0       0.0                  0.00
# 2016-01-11         33.0       8.0      37.0                 29.92
# 2016-01-12         35.0       0.0      53.0                 29.85
# 2016-01-13         26.0       4.0       0.0                 29.94
# 2016-01-14          0.0      12.0      47.0                  0.00
# 2016-01-17         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.fillna(method = 'ffill')   # Forward fill
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-03         36.0      18.0      47.0                 29.86
# 2016-01-06         33.0      18.0      35.0                 29.86
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-08         39.0      29.0      33.0                 30.20
# 2016-01-09         44.0      38.0      77.0                 30.16
# 2016-01-10         44.0      46.0      77.0                 30.16
# 2016-01-11         33.0       8.0      37.0                 29.92
# 2016-01-12         35.0       8.0      53.0                 29.85
# 2016-01-13         26.0       4.0      53.0                 29.94
# 2016-01-14         26.0      12.0      47.0                 29.94
# 2016-01-17         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.fillna(method = 'bfill')
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-03         33.0      11.0      47.0                 29.86
# 2016-01-06         33.0      11.0      35.0                 30.28
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-08         39.0      29.0      77.0                 30.20
# 2016-01-09         44.0      38.0      77.0                 30.16
# 2016-01-10         33.0      46.0      37.0                 29.92
# 2016-01-11         33.0       8.0      37.0                 29.92
# 2016-01-12         35.0       4.0      53.0                 29.85
# 2016-01-13         26.0       4.0      47.0                 29.94
# 2016-01-14         36.0      12.0      47.0                 29.78
# 2016-01-17         36.0      23.0      66.0                 29.78
# ...

# %%
weather_dataset.interpolate()
# Out:
#             Temperature   DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0  23.000000      52.0                 30.03
# 2016-01-02         36.0  18.000000      46.0                 30.02
# 2016-01-03         34.5  15.666667      47.0                 29.86
# 2016-01-06         33.0  13.333333      35.0                 30.07
# 2016-01-07         39.0  11.000000      33.0                 30.28
# 2016-01-08         39.0  29.000000      55.0                 30.20
# 2016-01-09         44.0  38.000000      77.0                 30.16
# 2016-01-10         38.5  46.000000      57.0                 30.04
# 2016-01-11         33.0   8.000000      37.0                 29.92
# 2016-01-12         35.0   6.000000      53.0                 29.85
# 2016-01-13         26.0   4.000000      50.0                 29.94
# 2016-01-14         31.0  12.000000      47.0                 29.86
# 2016-01-17         36.0  23.000000      66.0                 29.78
# ...

# %% [markdown]
# # Exporting the data frame

# %%
automobile_df = pd.DataFrame({'car_name' : ["Toyota Corolla Mark ii",
                                            "Chevrolet Chevelle Malibu",
                                            "Audi 100 LS",
                                            "BMW 2002",
                                            "Datsun PL510"],
                                   'mpg' : [24, 18, 24, 26, 27],
                            'horsepower' : [95, 130, 90, 113, 88],
                        'origin_country' : ["Japan", "US", "Germany", 
                                            "Germany", "Japan"]
    
                            })
automobile_df
# Out:
#                     car_name  mpg  horsepower origin_country
# 0     Toyota Corolla Mark ii   24          95          Japan
# 1  Chevrolet Chevelle Malibu   18         130             US
# 2                Audi 100 LS   24          90        Germany
# 3                   BMW 2002   26         113        Germany
# 4               Datsun PL510   27          88          Japan

# %%
automobile_df.to_csv('new_auto.csv')

# %%
automobile_df.to_excel('new_auto.xlsx')

# %%
weather_dataset.dropna()
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-02         36.0      18.0      46.0                 30.02
# 2016-01-07         39.0      11.0      33.0                 30.28
# 2016-01-17         36.0      23.0      66.0                 29.78
#
#             VisibilityMiles  WindSpeedMPH   Event
# Date
# 2016-01-01             10.0           8.0    Rain
# 2016-01-02             10.0           7.0   Sunny
# 2016-01-07             10.0           2.0  Cloudy
# 2016-01-17              8.0           6.0    Snow

# %%
weather_dataset.notna()
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         True      True      True                  True
# 2016-01-02         True      True      True                  True
# 2016-01-03        False     False      True                  True
# 2016-01-06         True     False      True                 False
# 2016-01-07         True      True      True                  True
# 2016-01-08         True      True     False                  True
# 2016-01-09         True      True      True                  True
# 2016-01-10        False      True     False                 False
# 2016-01-11         True      True      True                  True
# 2016-01-12         True     False      True                  True
# 2016-01-13         True      True     False                  True
# 2016-01-14        False      True      True                 False
# 2016-01-17         True      True      True                  True
# ...

# %%
weather_dataset.dropna().drop_duplicates('VisibilityMiles')
# Out:
#             Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# Date
# 2016-01-01         38.0      23.0      52.0                 30.03
# 2016-01-17         36.0      23.0      66.0                 29.78
#
#             VisibilityMiles  WindSpeedMPH Event
# Date
# 2016-01-01             10.0           8.0  Rain
# 2016-01-17              8.0           6.0  Snow
